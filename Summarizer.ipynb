# %% [markdown]
# # Extractive Text Summary using tfidf representation of text

# %% [markdown]
# This approach summarize a given text by discovering the important sentences with the help of sentences scores
# obtained from the presence of important words. And this importance is measured by a metric known as tf-idf,which
# tells how often any word appear in a document (tf:term frequency) and how often the documents contain the word (idf
# :inverse document frequency)                                                                                                                                                                                                                    .

# %%
#importing libraries
import math
import re
from nltk.corpus import stopwords

# %%
#for intake of text to be summarized
text=input("Enter Text to be Summarized:\n\n")
# Out:
# Enter Text to be Summarized:
#
# ﻿काठमाडौंमा पहिलो पटक स्ट्रबेरीको व्यवसायिक खेती सुरु भएको छ । एक दशकसम्म इजरायली कृषि फार्ममा बसेर काम गरेका श्रीकृष्ण अधिकारीले तारकेश्वर नगरपालिका ४ गोलढुंगामा उत्पादन सुरु गरेका हुन्। यसअघि स्ट्रबेरी नुवाकोटमा गरिँदै आएको थियो। अधिकारीले ५ रोपनी क्षेत्रफलमा १० हजार बिरुवा लगाएका छन्। १० हजार मध्ये १ प्रतिशत बिरुवा भने काम नलागेको अधिकारीले बताए। अहिलेसम्म नुवाकोटमा मात्रै यसको उत्पादन हुने भनिए पनि आफूले सुरुमा चुनौति मोलेर खेती सुरु गरेको उनले बताए। बीस–पच्चीस वर्षअघि ककनीमा जाइटी भन्ने संस्थाले स्ट्रबेरीको खेती सुरु गरेपछि नुवाकोटमा थालनी भएको थियो तर किसानहरुले नयाँ प्रविधिको प्रयोग गरेर भने खेती सुरु गरेका थिएनन्। अधिकारीले स्थापना गरेको सलोम एग्रीकल्चर नामक कम्पनीले कृषिमा आधुनिकीकरणका लागि विभिन्न खालका सेवा उपलब्ध गराउँदै आएको छ। ‘मैले नुवाकोटमा ग्रीन हाउस बनाउने थोपा सिँचाइको काम गरेको थिएँ’ उनले भने, ‘नुवाकोटमा गरेको आधारमा मैले काठमाडौंमा पनि स्ट्रबेरी लगाएको हो।’ अधिकारीको फर्ममा अहिले स्ट्रबेरी फल्न सुरु गरेको छ। भदौमा लगाएको स्ट्रबेरीले कात्तिकको तेश्रो साता देखि फलदिन सुरु गर्छ। मंसिरदेखि फागुनसम्म भने यसको उत्पादन राम्रोसँग हुन्छ। ५ देखि २५ डिग्री तापक्रममा स्ट्रबेरी लगाउन सकिन्छ। विशेष गरी जापान, कोरिया, थाइल्याण्ड, इजरायल लगायतका देशमा यसको उत्पादन हुन्छ। यी देशहरुले स्ट्रबेरीको निर्यात समेत गर्ने गरेका छन्। बालक देखि बृद्धसम्म यसको प्रयोग उपयोगी मानिएको छ। विभिन्न शुभ कार्यहरुमा समेत स्ट्रबेरीलाई प्याक गरेर उपहारको रुपमा दिइन्छ। जुनसुकै उमेर समुहका व्यक्तिका लागि पनि फाइदाजनक भएकोले ति देशहरुमा यसको उत्पादन बढ्दै गएको अधिकारीले बताए। ‘नेपालमा पनि स्ट्रबेरीको उत्पादन गर्न सके बजार राम्रो छ, अर्कोतिर निर्यात समेत गर्न सकिन्छ।’ उनले भने, ‘विदेशबाट आयात गर्ने फलफूलको विकल्पमा स्ट्रबेरीलाई लिन सकिन्छ।’ स्ट्रबेरीको जाम विश्वमै चर्चित रहेको उनले बताए। स्ट्रबेरीबाट रक्सी तथा जुस पनि बनाउन सकिन्छ।‘आफ्नो जति जग्गा छ त्यतिमा मात्रै खेती गर्न सके पनि यसले किसानलाई फाइदा पुग्छ।’ उनले भने, ‘यसले किसानको जीवनस्तरलाई त उकास्छ नै नेपालीहरु विदेसिनु समेत पर्दैन।’ विदेशमा लामो समयसम्म काम गरेकोले पनि आफूले स्वदेशमा बसेर केही गर्न खोजेको उनले बताए। विदेशमा बसेर काम गरेर फर्किएकाहरुको संस्था एसियन फोरमका सचिव समेत रहेका अधिकारीले पछिल्लो समयमा नेपालीहरुले आधुनिक प्रविधिको प्रयोग गरी कृषि पेशा अंगालेको बताए। ग्रीनहाउस बनाएर थोपा सिँचाई मार्फत आफूले देशका विभिन्न ठाउँहरुमा तरकारी खेती गर्ने सेवा उपलब्ध गराएको अधिकारीको भनाइ छ। नेपालमा पहिलोपटक थोपा सिंचाइलाई व्यवसायिक रुपमा आफैले प्रयोग गरेको उनले दावी गरे।

# %%
len(text)
# Out:
# 2347

# %%
#sentences tokenization
sents=re.split('।',text)

# %%
print(sents)
# Out:
# ['\ufeffकाठमाडौंमा पहिलो पटक स्ट्रबेरीको व्यवसायिक खेती सुरु भएको छ ', ' एक दशकसम्म इजरायली कृषि फार्ममा बसेर काम गरेका श्रीकृष्ण अधिकारीले तारकेश्वर नगरपालिका ४ गोलढुंगामा उत्पादन सुरु गरेका हुन्', ' यसअघि स्ट्रबेरी नुवाकोटमा गरिँदै आएको थियो', ' अधिकारीले ५ रोपनी क्षेत्रफलमा १० हजार बिरुवा लगाएका छन्', ' १० हजार मध्ये १ प्रतिशत बिरुवा भने काम नलागेको अधिकारीले बताए', ' अहिलेसम्म नुवाकोटमा मात्रै यसको उत्पादन हुने भनिए पनि आफूले सुरुमा चुनौति मोलेर खेती सुरु गरेको उनले बताए', ' बीस–पच्चीस वर्षअघि ककनीमा जाइटी भन्ने संस्थाले स्ट्रबेरीको खेती सुरु गरेपछि नुवाकोटमा थालनी भएको थियो तर किसानहरुले नयाँ प्रविधिको प्रयोग गरेर भने खेती सुरु गरेका थिएनन्', ' अधिकारीले स्थापना गरेको सलोम एग्रीकल्चर नामक कम्पनीले कृषिमा आधुनिकीकरणका लागि विभिन्न खालका सेवा उपलब्ध गराउँदै आएको छ', ' ‘मैले नुवाकोटमा ग्रीन हाउस बनाउने थोपा सिँचाइको काम गरेको थिएँ’ उनले भने, ‘नुवाकोटमा गरेको आधारमा मैले काठमाडौंमा पनि स्ट्रबेरी लगाएको हो', '’ अधिकारीको फर्ममा अहिले स्ट्रबेरी फल्न सुरु गरेको छ', ' भदौमा लगाएको स्ट्रबेरीले कात्तिकको तेश्रो साता देखि फलदिन सुरु गर्छ', ' मंसिरदेखि फागुनसम्म भने यसको उत्पादन राम्रोसँग हुन्छ', ' ५ देखि २५ डिग्री तापक्रममा स्ट्रबेरी लगाउन सकिन्छ', ' विशेष गरी जापान, कोरिया, थाइल्याण्ड, इजरायल लगायतका देशमा यसको उत्पादन हुन्छ', ' यी देशहरुले स्ट्रबेरीको निर्यात समेत गर्ने गरेका छन्', ' बालक देखि बृद्धसम्म यसको प्रयोग उपयोगी मानिएको छ', ' विभिन्न शुभ कार्यहरुमा समेत स्ट्रबेरीलाई प्याक गरेर उपहारको रुपमा दिइन्छ', ' जुनसुकै उमेर समुहका व्यक्तिका लागि पनि फाइदाजनक भएकोले ति देशहरुमा यसको उत्पादन बढ्दै गएको अधिकारीले बताए', ' ‘नेपालमा पनि स्ट्रबेरीको उत्पादन गर्न सके बजार राम्रो छ, अर्कोतिर निर्यात समेत गर्न सकिन्छ', '’ उनले भने, ‘विदेशबाट आयात गर्ने फलफूलको विकल्पमा स्ट्रबेरीलाई लिन सकिन्छ', '’ स्ट्रबेरीको जाम विश्वमै चर्चित रहेको उनले बताए', ' स्ट्रबेरीबाट रक्सी तथा जुस पनि बनाउन सकिन्छ', '‘आफ्नो जति जग्गा छ त्यतिमा मात्रै खेती गर्न सके पनि यसले किसानलाई फाइदा पुग्छ', '’ उनले भने, ‘यसले किसानको जीवनस्तरलाई त उकास्छ नै नेपालीहरु विदेसिनु समेत पर्दैन', '’ विदेशमा लामो समयसम्म काम गरेकोले पनि आफूले स्वदेशमा बसेर केही गर्न खोजेको उनले बताए', ' विदेशमा बसेर काम गरेर फर्किएकाहरुको संस्था एसियन फोरमका सचिव समेत रहेका अधिकारीले पछिल्लो समयमा नेपालीहरुले आधुनिक प्रविधिको प्रयोग गरी कृषि पेशा अंगालेको बताए', ' ग्रीनहाउस बनाएर थोपा सिँचाई मार्फत आफूले देशका विभिन्न ठाउँहरुमा तरकारी खेती गर्ने सेवा उपलब्ध गराएको अधिकारीको भनाइ छ', ' नेपालमा पहिलोपटक थोपा सिंचाइलाई व्यवसायिक रुपमा आफैले प्रयोग गरेको उनले दावी गरे', '']

# %%
documents_size = len(sents)

# %%
documents_size
# Out:
# 29

# %%
words=text.split()

# %% [markdown]
# ## creating word frequency

# %%
def create_frequency_matrix(sentences):
    frequency_matrix = {}
    stopWords = set(stopwords.words("nepali"))

    for sent in sentences:
        freq_table = {}
        words=sent.split()
        for word in words:
            if word in stopWords:
                continue

            if word in freq_table:
                freq_table[word] += 1
            else:
                freq_table[word] = 1

        frequency_matrix[sent[:10]] = freq_table

    return frequency_matrix

# %%
freq_matrix = create_frequency_matrix(sents)

# %%
freq_matrix
# Out:
# {'\ufeffकाठमाडौंम': {'\ufeffकाठमाडौंमा': 1,
#   'स्ट्रबेरीको': 1,
#   'व्यवसायिक': 1,
#   'खेती': 1,
#   'सुरु': 1},
#  ' एक दशकसम्': {'दशकसम्म': 1,
#   'इजरायली': 1,
#   'कृषि': 1,
#   'फार्ममा': 1,
#   'बसेर': 1,
#   'काम': 1,
#   'श्रीकृष्ण': 1,
#   'अधिकारीले': 1,
#   'तारकेश्वर': 1,
#   'नगरपालिका': 1,
#   '४': 1,
#   'गोलढुंगामा': 1,
#   'उत्पादन': 1,
#   'सुरु': 1},
#  ' यसअघि स्ट': {'यसअघि': 1,
#   'स्ट्रबेरी': 1,
#   'नुवाकोटमा': 1,
#   'गरिँदै': 1,
#   'आएको': 1},
#  ' अधिकारीले': {'अधिकारीले': 1,
#   'स्थापना': 1,
#   'सलोम': 1,
#   'एग्रीकल्चर': 1,
#   'नामक': 1,
#   'कम्पनीले': 1,
#   'कृषिमा': 1,
#   'आधुनिकीकरणका': 1,
#   'विभिन्न': 1,
#   'खालका': 1,
#   'सेवा': 1,
#   'उपलब्ध': 1,
#   'गराउँदै': 1,
#   'आएको': 1},
#  ' १० हजार म': {'१०': 1,
#   'हजार': 1,
#   'मध्ये': 1,
#   '१': 1,
#   'प्रतिशत': 1,
#   'बिरुवा': 1,
#   'काम': 1,
#   'नलागेको': 1,
#   'अधिकारीले': 1,
#   'बताए': 1},
#  ' अहिलेसम्म': {'अहिलेसम्म': 1,
#   'नुवाकोटमा': 1,
#   'मात्रै': 1,
#   'उत्पादन': 1,
#   'भनिए': 1,
#   'आफूले': 1,
#   'सुरुमा': 1,
#   'चुनौति': 1,
#   'मोलेर': 1,
#   'खेती': 1,
#   'सुरु': 1,
#   'बताए': 1},
#  ' बीस–पच्ची': {'बीस–पच्चीस': 1,
#   'वर्षअघि': 1,
#   'ककनीमा': 1,
#   'जाइटी': 1,
#   'संस्थाले': 1,
#   'स्ट्रबेरीको': 1,
#   'खेती': 2,
#   'सुरु': 2,
#   'गरेपछि': 1,
#   'नुवाकोटमा': 1,
#   'थालनी': 1,
#   'किसानहरुले': 1,
#   'प्रविधिको': 1,
#   'प्रयोग': 1,
#   'थिएनन्': 1},
#  ' ‘मैले नुव': {'‘मैले': 1,
#   'नुवाकोटमा': 1,
#   'ग्रीन': 1,
#   'हाउस': 1,
#   'बनाउने': 1,
#   'थोपा': 1,
#   'सिँचाइको': 1,
#   'काम': 1,
#   'थिएँ’': 1,
#   'भने,': 1,
#   '‘नुवाकोटमा': 1,
#   'आधारमा': 1,
#   'मैले': 1,
#   'काठमाडौंमा': 1,
#   'स्ट्रबेरी': 1,
#   'लगाएको': 1},
#  '’ अधिकारीक': {'’': 1,
#   'अधिकारीको': 1,
#   'फर्ममा': 1,
#   'अहिले': 1,
#   'स्ट्रबेरी': 1,
#   'फल्न': 1,
#   'सुरु': 1},
#  ' भदौमा लगा': {'भदौमा': 1,
#   'लगाएको': 1,
#   'स्ट्रबेरीले': 1,
#   'कात्तिकको': 1,
#   'तेश्रो': 1,
#   'साता': 1,
#   'फलदिन': 1,
#   'सुरु': 1},
#  ' मंसिरदेखि': {'मंसिरदेखि': 1, 'फागुनसम्म': 1, 'उत्पादन': 1, 'राम्रोसँग': 1},
#  ' ५ देखि २५': {'५': 1,
#   '२५': 1,
#   'डिग्री': 1,
#   'तापक्रममा': 1,
#   'स्ट्रबेरी': 1,
#   'लगाउन': 1,
#   'सकिन्छ': 1},
#  ' विशेष गरी': {'विशेष': 1,
#   'जापान,': 1,
#   'कोरिया,': 1,
#   'थाइल्याण्ड,': 1,
#   'इजरायल': 1,
#   'लगायतका': 1,
#   'देशमा': 1,
#   'उत्पादन': 1},
#  ' यी देशहरु': {'देशहरुले': 1, 'स्ट्रबेरीको': 1, 'निर्यात': 1, 'समेत': 1},
#  ' बालक देखि': {'बालक': 1,
#   'बृद्धसम्म': 1,
#   'प्रयोग': 1,
#   'उपयोगी': 1,
#   'मानिएको': 1},
#  ' विभिन्न श': {'विभिन्न': 1,
#   'शुभ': 1,
#   'कार्यहरुमा': 1,
#   'समेत': 1,
#   'स्ट्रबेरीलाई': 1,
#   'प्याक': 1,
#   'उपहारको': 1,
#   'रुपमा': 1,
#   'दिइन्छ': 1},
#  ' जुनसुकै उ': {'जुनसुकै': 1,
#   'उमेर': 1,
#   'समुहका': 1,
#   'व्यक्तिका': 1,
#   'फाइदाजनक': 1,
#   'भएकोले': 1,
#   'ति': 1,
#   'देशहरुमा': 1,
#   'उत्पादन': 1,
#   'बढ्दै': 1,
#   'गएको': 1,
#   'अधिकारीले': 1,
#   'बताए': 1},
#  ' ‘नेपालमा ': {'‘नेपालमा': 1,
#   'स्ट्रबेरीको': 1,
#   'उत्पादन': 1,
#   'सके': 1,
#   'बजार': 1,
#   'छ,': 1,
#   'अर्कोतिर': 1,
#   'निर्यात': 1,
#   'समेत': 1,
#   'सकिन्छ': 1},
#  '’ उनले भने': {'’': 1,
#   'भने,': 1,
#   '‘यसले': 1,
#   'किसानको': 1,
#   'जीवनस्तरलाई': 1,
#   'उकास्छ': 1,
#   'नेपालीहरु': 1,
#   'विदेसिनु': 1,
#   'समेत': 1,
#   'पर्दैन': 1},
#  '’ स्ट्रबेर': {'’': 1,
#   'स्ट्रबेरीको': 1,
#   'जाम': 1,
#   'विश्वमै': 1,
#   'चर्चित': 1,
#   'बताए': 1},
#  ' स्ट्रबेरी': {'स्ट्रबेरीबाट': 1,
#   'रक्सी': 1,
#   'जुस': 1,
#   'बनाउन': 1,
#   'सकिन्छ': 1},
#  '‘आफ्नो जति': {'‘आफ्नो': 1,
#   'जति': 1,
#   'जग्गा': 1,
#   'त्यतिमा': 1,
#   'मात्रै': 1,
#   'खेती': 1,
#   'सके': 1,
#   'यसले': 1,
#   'किसानलाई': 1,
#   'फाइदा': 1,
#   'पुग्छ': 1},
#  '’ विदेशमा ': {'’': 1,
#   'विदेशमा': 1,
#   'लामो': 1,
#   'समयसम्म': 1,
#   'काम': 1,
#   'गरेकोले': 1,
#   'आफूले': 1,
#   'स्वदेशमा': 1,
#   'बसेर': 1,
#   'खोजेको': 1,
#   'बताए': 1},
#  ' विदेशमा ब': {'विदेशमा': 1,
#   'बसेर': 1,
#   'काम': 1,
#   'फर्किएकाहरुको': 1,
#   'संस्था': 1,
#   'एसियन': 1,
#   'फोरमका': 1,
#   'सचिव': 1,
#   'समेत': 1,
#   'अधिकारीले': 1,
#   'समयमा': 1,
#   'नेपालीहरुले': 1,
#   'आधुनिक': 1,
#   'प्रविधिको': 1,
#   'प्रयोग': 1,
#   'कृषि': 1,
#   'पेशा': 1,
#   'अंगालेको': 1,
#   'बताए': 1},
#  ' ग्रीनहाउस': {'ग्रीनहाउस': 1,
#   'बनाएर': 1,
#   'थोपा': 1,
#   'सिँचाई': 1,
#   'मार्फत': 1,
#   'आफूले': 1,
#   'देशका': 1,
#   'विभिन्न': 1,
#   'ठाउँहरुमा': 1,
#   'तरकारी': 1,
#   'खेती': 1,
#   'सेवा': 1,
#   'उपलब्ध': 1,
#   'गराएको': 1,
#   'अधिकारीको': 1,
#   'भनाइ': 1},
#  ' नेपालमा प': {'नेपालमा': 1,
#   'पहिलोपटक': 1,
#   'थोपा': 1,
#   'सिंचाइलाई': 1,
#   'व्यवसायिक': 1,
#   'रुपमा': 1,
#   'आफैले': 1,
#   'प्रयोग': 1,
#   'दावी': 1,
#   'गरे': 1},
#  '': {}}

# %% [markdown]
# ## creating term frequency matrix

# %%
def create_tf_matrix(freq_matrix):
    tf_matrix = {}

    for sent, f_table in freq_matrix.items():
        tf_table = {}

        count_words_in_sentence = len(f_table)
        for word, count in f_table.items():
            tf_table[word] = count / count_words_in_sentence

        tf_matrix[sent] = tf_table

    return tf_matrix

# %%
tf_matrix = create_tf_matrix(freq_matrix)

# %%
tf_matrix
# Out:
# {'\ufeffकाठमाडौंम': {'\ufeffकाठमाडौंमा': 0.2,
#   'स्ट्रबेरीको': 0.2,
#   'व्यवसायिक': 0.2,
#   'खेती': 0.2,
#   'सुरु': 0.2},
#  ' एक दशकसम्': {'दशकसम्म': 0.07142857142857142,
#   'इजरायली': 0.07142857142857142,
#   'कृषि': 0.07142857142857142,
#   'फार्ममा': 0.07142857142857142,
#   'बसेर': 0.07142857142857142,
#   'काम': 0.07142857142857142,
#   'श्रीकृष्ण': 0.07142857142857142,
#   'अधिकारीले': 0.07142857142857142,
#   'तारकेश्वर': 0.07142857142857142,
#   'नगरपालिका': 0.07142857142857142,
#   '४': 0.07142857142857142,
#   'गोलढुंगामा': 0.07142857142857142,
#   'उत्पादन': 0.07142857142857142,
#   'सुरु': 0.07142857142857142},
#  ' यसअघि स्ट': {'यसअघि': 0.2,
#   'स्ट्रबेरी': 0.2,
#   'नुवाकोटमा': 0.2,
#   'गरिँदै': 0.2,
#   'आएको': 0.2},
#  ' अधिकारीले': {'अधिकारीले': 0.07142857142857142,
#   'स्थापना': 0.07142857142857142,
#   'सलोम': 0.07142857142857142,
#   'एग्रीकल्चर': 0.07142857142857142,
#   'नामक': 0.07142857142857142,
#   'कम्पनीले': 0.07142857142857142,
#   'कृषिमा': 0.07142857142857142,
#   'आधुनिकीकरणका': 0.07142857142857142,
#   'विभिन्न': 0.07142857142857142,
#   'खालका': 0.07142857142857142,
#   'सेवा': 0.07142857142857142,
#   'उपलब्ध': 0.07142857142857142,
#   'गराउँदै': 0.07142857142857142,
#   'आएको': 0.07142857142857142},
#  ' १० हजार म': {'१०': 0.1,
#   'हजार': 0.1,
#   'मध्ये': 0.1,
#   '१': 0.1,
#   'प्रतिशत': 0.1,
#   'बिरुवा': 0.1,
#   'काम': 0.1,
#   'नलागेको': 0.1,
#   'अधिकारीले': 0.1,
#   'बताए': 0.1},
#  ' अहिलेसम्म': {'अहिलेसम्म': 0.08333333333333333,
#   'नुवाकोटमा': 0.08333333333333333,
#   'मात्रै': 0.08333333333333333,
#   'उत्पादन': 0.08333333333333333,
#   'भनिए': 0.08333333333333333,
#   'आफूले': 0.08333333333333333,
#   'सुरुमा': 0.08333333333333333,
#   'चुनौति': 0.08333333333333333,
#   'मोलेर': 0.08333333333333333,
#   'खेती': 0.08333333333333333,
#   'सुरु': 0.08333333333333333,
#   'बताए': 0.08333333333333333},
#  ' बीस–पच्ची': {'बीस–पच्चीस': 0.06666666666666667,
#   'वर्षअघि': 0.06666666666666667,
#   'ककनीमा': 0.06666666666666667,
#   'जाइटी': 0.06666666666666667,
#   'संस्थाले': 0.06666666666666667,
#   'स्ट्रबेरीको': 0.06666666666666667,
#   'खेती': 0.13333333333333333,
#   'सुरु': 0.13333333333333333,
#   'गरेपछि': 0.06666666666666667,
#   'नुवाकोटमा': 0.06666666666666667,
#   'थालनी': 0.06666666666666667,
#   'किसानहरुले': 0.06666666666666667,
#   'प्रविधिको': 0.06666666666666667,
#   'प्रयोग': 0.06666666666666667,
#   'थिएनन्': 0.06666666666666667},
#  ' ‘मैले नुव': {'‘मैले': 0.0625,
#   'नुवाकोटमा': 0.0625,
#   'ग्रीन': 0.0625,
#   'हाउस': 0.0625,
#   'बनाउने': 0.0625,
#   'थोपा': 0.0625,
#   'सिँचाइको': 0.0625,
#   'काम': 0.0625,
#   'थिएँ’': 0.0625,
#   'भने,': 0.0625,
#   '‘नुवाकोटमा': 0.0625,
#   'आधारमा': 0.0625,
#   'मैले': 0.0625,
#   'काठमाडौंमा': 0.0625,
#   'स्ट्रबेरी': 0.0625,
#   'लगाएको': 0.0625},
#  '’ अधिकारीक': {'’': 0.14285714285714285,
#   'अधिकारीको': 0.14285714285714285,
#   'फर्ममा': 0.14285714285714285,
#   'अहिले': 0.14285714285714285,
#   'स्ट्रबेरी': 0.14285714285714285,
#   'फल्न': 0.14285714285714285,
#   'सुरु': 0.14285714285714285},
#  ' भदौमा लगा': {'भदौमा': 0.125,
#   'लगाएको': 0.125,
#   'स्ट्रबेरीले': 0.125,
#   'कात्तिकको': 0.125,
#   'तेश्रो': 0.125,
#   'साता': 0.125,
#   'फलदिन': 0.125,
#   'सुरु': 0.125},
#  ' मंसिरदेखि': {'मंसिरदेखि': 0.25,
#   'फागुनसम्म': 0.25,
#   'उत्पादन': 0.25,
#   'राम्रोसँग': 0.25},
#  ' ५ देखि २५': {'५': 0.14285714285714285,
#   '२५': 0.14285714285714285,
#   'डिग्री': 0.14285714285714285,
#   'तापक्रममा': 0.14285714285714285,
#   'स्ट्रबेरी': 0.14285714285714285,
#   'लगाउन': 0.14285714285714285,
#   'सकिन्छ': 0.14285714285714285},
#  ' विशेष गरी': {'विशेष': 0.125,
#   'जापान,': 0.125,
#   'कोरिया,': 0.125,
#   'थाइल्याण्ड,': 0.125,
#   'इजरायल': 0.125,
#   'लगायतका': 0.125,
#   'देशमा': 0.125,
#   'उत्पादन': 0.125},
#  ' यी देशहरु': {'देशहरुले': 0.25,
#   'स्ट्रबेरीको': 0.25,
#   'निर्यात': 0.25,
#   'समेत': 0.25},
#  ' बालक देखि': {'बालक': 0.2,
#   'बृद्धसम्म': 0.2,
#   'प्रयोग': 0.2,
#   'उपयोगी': 0.2,
#   'मानिएको': 0.2},
#  ' विभिन्न श': {'विभिन्न': 0.1111111111111111,
#   'शुभ': 0.1111111111111111,
#   'कार्यहरुमा': 0.1111111111111111,
#   'समेत': 0.1111111111111111,
#   'स्ट्रबेरीलाई': 0.1111111111111111,
#   'प्याक': 0.1111111111111111,
#   'उपहारको': 0.1111111111111111,
#   'रुपमा': 0.1111111111111111,
#   'दिइन्छ': 0.1111111111111111},
#  ' जुनसुकै उ': {'जुनसुकै': 0.07692307692307693,
#   'उमेर': 0.07692307692307693,
#   'समुहका': 0.07692307692307693,
#   'व्यक्तिका': 0.07692307692307693,
#   'फाइदाजनक': 0.07692307692307693,
#   'भएकोले': 0.07692307692307693,
#   'ति': 0.07692307692307693,
#   'देशहरुमा': 0.07692307692307693,
#   'उत्पादन': 0.07692307692307693,
#   'बढ्दै': 0.07692307692307693,
#   'गएको': 0.07692307692307693,
#   'अधिकारीले': 0.07692307692307693,
#   'बताए': 0.07692307692307693},
#  ' ‘नेपालमा ': {'‘नेपालमा': 0.1,
#   'स्ट्रबेरीको': 0.1,
#   'उत्पादन': 0.1,
#   'सके': 0.1,
#   'बजार': 0.1,
#   'छ,': 0.1,
#   'अर्कोतिर': 0.1,
#   'निर्यात': 0.1,
#   'समेत': 0.1,
#   'सकिन्छ': 0.1},
#  '’ उनले भने': {'’': 0.1,
#   'भने,': 0.1,
#   '‘यसले': 0.1,
#   'किसानको': 0.1,
#   'जीवनस्तरलाई': 0.1,
#   'उकास्छ': 0.1,
#   'नेपालीहरु': 0.1,
#   'विदेसिनु': 0.1,
#   'समेत': 0.1,
#   'पर्दैन': 0.1},
#  '’ स्ट्रबेर': {'’': 0.16666666666666666,
#   'स्ट्रबेरीको': 0.16666666666666666,
#   'जाम': 0.16666666666666666,
#   'विश्वमै': 0.16666666666666666,
#   'चर्चित': 0.16666666666666666,
#   'बताए': 0.16666666666666666},
#  ' स्ट्रबेरी': {'स्ट्रबेरीबाट': 0.2,
#   'रक्सी': 0.2,
#   'जुस': 0.2,
#   'बनाउन': 0.2,
#   'सकिन्छ': 0.2},
#  '‘आफ्नो जति': {'‘आफ्नो': 0.09090909090909091,
#   'जति': 0.09090909090909091,
#   'जग्गा': 0.09090909090909091,
#   'त्यतिमा': 0.09090909090909091,
#   'मात्रै': 0.09090909090909091,
#   'खेती': 0.09090909090909091,
#   'सके': 0.09090909090909091,
#   'यसले': 0.09090909090909091,
#   'किसानलाई': 0.09090909090909091,
#   'फाइदा': 0.09090909090909091,
#   'पुग्छ': 0.09090909090909091},
#  '’ विदेशमा ': {'’': 0.09090909090909091,
#   'विदेशमा': 0.09090909090909091,
#   'लामो': 0.09090909090909091,
#   'समयसम्म': 0.09090909090909091,
#   'काम': 0.09090909090909091,
#   'गरेकोले': 0.09090909090909091,
#   'आफूले': 0.09090909090909091,
#   'स्वदेशमा': 0.09090909090909091,
#   'बसेर': 0.09090909090909091,
#   'खोजेको': 0.09090909090909091,
#   'बताए': 0.09090909090909091},
#  ' विदेशमा ब': {'विदेशमा': 0.05263157894736842,
#   'बसेर': 0.05263157894736842,
#   'काम': 0.05263157894736842,
#   'फर्किएकाहरुको': 0.05263157894736842,
#   'संस्था': 0.05263157894736842,
#   'एसियन': 0.05263157894736842,
#   'फोरमका': 0.05263157894736842,
#   'सचिव': 0.05263157894736842,
#   'समेत': 0.05263157894736842,
#   'अधिकारीले': 0.05263157894736842,
#   'समयमा': 0.05263157894736842,
#   'नेपालीहरुले': 0.05263157894736842,
#   'आधुनिक': 0.05263157894736842,
#   'प्रविधिको': 0.05263157894736842,
#   'प्रयोग': 0.05263157894736842,
#   'कृषि': 0.05263157894736842,
#   'पेशा': 0.05263157894736842,
#   'अंगालेको': 0.05263157894736842,
#   'बताए': 0.05263157894736842},
#  ' ग्रीनहाउस': {'ग्रीनहाउस': 0.0625,
#   'बनाएर': 0.0625,
#   'थोपा': 0.0625,
#   'सिँचाई': 0.0625,
#   'मार्फत': 0.0625,
#   'आफूले': 0.0625,
#   'देशका': 0.0625,
#   'विभिन्न': 0.0625,
#   'ठाउँहरुमा': 0.0625,
#   'तरकारी': 0.0625,
#   'खेती': 0.0625,
#   'सेवा': 0.0625,
#   'उपलब्ध': 0.0625,
#   'गराएको': 0.0625,
#   'अधिकारीको': 0.0625,
#   'भनाइ': 0.0625},
#  ' नेपालमा प': {'नेपालमा': 0.1,
#   'पहिलोपटक': 0.1,
#   'थोपा': 0.1,
#   'सिंचाइलाई': 0.1,
#   'व्यवसायिक': 0.1,
#   'रुपमा': 0.1,
#   'आफैले': 0.1,
#   'प्रयोग': 0.1,
#   'दावी': 0.1,
#   'गरे': 0.1},
#  '': {}}

# %% [markdown]
# ## calculating docs per words

# %%
def create_documents_per_words(freq_matrix):
    word_per_doc_table = {}

    for sent, f_table in freq_matrix.items():
        for word, count in f_table.items():
            if word in word_per_doc_table:
                word_per_doc_table[word] += 1
            else:
                word_per_doc_table[word] = 1

    return word_per_doc_table

# %%
count_doc_per_words = create_documents_per_words(freq_matrix)

# %%
count_doc_per_words
# Out:
# {'\ufeffकाठमाडौंमा': 1,
#  'स्ट्रबेरीको': 5,
#  'व्यवसायिक': 2,
#  'खेती': 5,
#  'सुरु': 6,
#  'दशकसम्म': 1,
#  'इजरायली': 1,
#  'कृषि': 2,
#  'फार्ममा': 1,
#  'बसेर': 3,
#  'काम': 5,
#  'श्रीकृष्ण': 1,
#  'अधिकारीले': 5,
#  'तारकेश्वर': 1,
#  'नगरपालिका': 1,
#  '४': 1,
#  'गोलढुंगामा': 1,
#  'उत्पादन': 6,
#  'यसअघि': 1,
#  'स्ट्रबेरी': 4,
#  'नुवाकोटमा': 4,
#  'गरिँदै': 1,
#  'आएको': 2,
#  'स्थापना': 1,
#  'सलोम': 1,
#  'एग्रीकल्चर': 1,
#  'नामक': 1,
#  'कम्पनीले': 1,
#  'कृषिमा': 1,
#  'आधुनिकीकरणका': 1,
#  'विभिन्न': 3,
#  'खालका': 1,
#  'सेवा': 2,
#  'उपलब्ध': 2,
#  'गराउँदै': 1,
#  '१०': 1,
#  'हजार': 1,
#  'मध्ये': 1,
#  '१': 1,
#  'प्रतिशत': 1,
#  'बिरुवा': 1,
#  'नलागेको': 1,
#  'बताए': 6,
#  'अहिलेसम्म': 1,
#  'मात्रै': 2,
#  'भनिए': 1,
#  'आफूले': 3,
#  'सुरुमा': 1,
#  'चुनौति': 1,
#  'मोलेर': 1,
#  'बीस–पच्चीस': 1,
#  'वर्षअघि': 1,
#  'ककनीमा': 1,
#  'जाइटी': 1,
#  'संस्थाले': 1,
#  'गरेपछि': 1,
#  'थालनी': 1,
#  'किसानहरुले': 1,
#  'प्रविधिको': 2,
#  'प्रयोग': 4,
#  'थिएनन्': 1,
#  '‘मैले': 1,
#  'ग्रीन': 1,
#  'हाउस': 1,
#  'बनाउने': 1,
#  'थोपा': 3,
#  'सिँचाइको': 1,
#  'थिएँ’': 1,
#  'भने,': 2,
#  '‘नुवाकोटमा': 1,
#  'आधारमा': 1,
#  'मैले': 1,
#  'काठमाडौंमा': 1,
#  'लगाएको': 2,
#  '’': 4,
#  'अधिकारीको': 2,
#  'फर्ममा': 1,
#  'अहिले': 1,
#  'फल्न': 1,
#  'भदौमा': 1,
#  'स्ट्रबेरीले': 1,
#  'कात्तिकको': 1,
#  'तेश्रो': 1,
#  'साता': 1,
#  'फलदिन': 1,
#  'मंसिरदेखि': 1,
#  'फागुनसम्म': 1,
#  'राम्रोसँग': 1,
#  '५': 1,
#  '२५': 1,
#  'डिग्री': 1,
#  'तापक्रममा': 1,
#  'लगाउन': 1,
#  'सकिन्छ': 3,
#  'विशेष': 1,
#  'जापान,': 1,
#  'कोरिया,': 1,
#  'थाइल्याण्ड,': 1,
#  'इजरायल': 1,
#  'लगायतका': 1,
#  'देशमा': 1,
#  'देशहरुले': 1,
#  'निर्यात': 2,
#  'समेत': 5,
#  'बालक': 1,
#  'बृद्धसम्म': 1,
#  'उपयोगी': 1,
#  'मानिएको': 1,
#  'शुभ': 1,
#  'कार्यहरुमा': 1,
#  'स्ट्रबेरीलाई': 1,
#  'प्याक': 1,
#  'उपहारको': 1,
#  'रुपमा': 2,
#  'दिइन्छ': 1,
#  'जुनसुकै': 1,
#  'उमेर': 1,
#  'समुहका': 1,
#  'व्यक्तिका': 1,
#  'फाइदाजनक': 1,
#  'भएकोले': 1,
#  'ति': 1,
#  'देशहरुमा': 1,
#  'बढ्दै': 1,
#  'गएको': 1,
#  '‘नेपालमा': 1,
#  'सके': 2,
#  'बजार': 1,
#  'छ,': 1,
#  'अर्कोतिर': 1,
#  '‘यसले': 1,
#  'किसानको': 1,
#  'जीवनस्तरलाई': 1,
#  'उकास्छ': 1,
#  'नेपालीहरु': 1,
#  'विदेसिनु': 1,
#  'पर्दैन': 1,
#  'जाम': 1,
#  'विश्वमै': 1,
#  'चर्चित': 1,
#  'स्ट्रबेरीबाट': 1,
#  'रक्सी': 1,
#  'जुस': 1,
#  'बनाउन': 1,
#  '‘आफ्नो': 1,
#  'जति': 1,
#  'जग्गा': 1,
#  'त्यतिमा': 1,
#  'यसले': 1,
#  'किसानलाई': 1,
#  'फाइदा': 1,
#  'पुग्छ': 1,
#  'विदेशमा': 2,
#  'लामो': 1,
#  'समयसम्म': 1,
#  'गरेकोले': 1,
#  'स्वदेशमा': 1,
#  'खोजेको': 1,
#  'फर्किएकाहरुको': 1,
#  'संस्था': 1,
#  'एसियन': 1,
#  'फोरमका': 1,
#  'सचिव': 1,
#  'समयमा': 1,
#  'नेपालीहरुले': 1,
#  'आधुनिक': 1,
#  'पेशा': 1,
#  'अंगालेको': 1,
#  'ग्रीनहाउस': 1,
#  'बनाएर': 1,
#  'सिँचाई': 1,
#  'मार्फत': 1,
#  'देशका': 1,
#  'ठाउँहरुमा': 1,
#  'तरकारी': 1,
#  'गराएको': 1,
#  'भनाइ': 1,
#  'नेपालमा': 1,
#  'पहिलोपटक': 1,
#  'सिंचाइलाई': 1,
#  'आफैले': 1,
#  'दावी': 1,
#  'गरे': 1}

# %% [markdown]
# ## creating inverse document frequency matrix

# %%
def create_idf_matrix(freq_matrix, count_doc_per_words, documents_size):
    idf_matrix = {}

    for sent, f_table in freq_matrix.items():
        idf_table = {}

        for word in f_table.keys():
            idf_table[word] = math.log10(documents_size / float(count_doc_per_words[word]))

        idf_matrix[sent] = idf_table

    return idf_matrix

# %%
idf_matrix = create_idf_matrix(freq_matrix, count_doc_per_words, documents_size)

# %%
idf_matrix
# Out:
# {'\ufeffकाठमाडौंम': {'\ufeffकाठमाडौंमा': 1.462397997898956,
#   'स्ट्रबेरीको': 0.7634279935629373,
#   'व्यवसायिक': 1.1613680022349748,
#   'खेती': 0.7634279935629373,
#   'सुरु': 0.6842467475153124},
#  ' एक दशकसम्': {'दशकसम्म': 1.462397997898956,
#   'इजरायली': 1.462397997898956,
#   'कृषि': 1.1613680022349748,
#   'फार्ममा': 1.462397997898956,
#   'बसेर': 0.9852767431792936,
#   'काम': 0.7634279935629373,
#   'श्रीकृष्ण': 1.462397997898956,
#   'अधिकारीले': 0.7634279935629373,
#   'तारकेश्वर': 1.462397997898956,
#   'नगरपालिका': 1.462397997898956,
#   '४': 1.462397997898956,
#   'गोलढुंगामा': 1.462397997898956,
#   'उत्पादन': 0.6842467475153124,
#   'सुरु': 0.6842467475153124},
#  ' यसअघि स्ट': {'यसअघि': 1.462397997898956,
#   'स्ट्रबेरी': 0.8603380065709937,
#   'नुवाकोटमा': 0.8603380065709937,
#   'गरिँदै': 1.462397997898956,
#   'आएको': 1.1613680022349748},
#  ' अधिकारीले': {'अधिकारीले': 0.7634279935629373,
#   'स्थापना': 1.462397997898956,
#   'सलोम': 1.462397997898956,
#   'एग्रीकल्चर': 1.462397997898956,
#   'नामक': 1.462397997898956,
#   'कम्पनीले': 1.462397997898956,
#   'कृषिमा': 1.462397997898956,
#   'आधुनिकीकरणका': 1.462397997898956,
#   'विभिन्न': 0.9852767431792936,
#   'खालका': 1.462397997898956,
#   'सेवा': 1.1613680022349748,
#   'उपलब्ध': 1.1613680022349748,
#   'गराउँदै': 1.462397997898956,
#   'आएको': 1.1613680022349748},
#  ' १० हजार म': {'१०': 1.462397997898956,
#   'हजार': 1.462397997898956,
#   'मध्ये': 1.462397997898956,
#   '१': 1.462397997898956,
#   'प्रतिशत': 1.462397997898956,
#   'बिरुवा': 1.462397997898956,
#   'काम': 0.7634279935629373,
#   'नलागेको': 1.462397997898956,
#   'अधिकारीले': 0.7634279935629373,
#   'बताए': 0.6842467475153124},
#  ' अहिलेसम्म': {'अहिलेसम्म': 1.462397997898956,
#   'नुवाकोटमा': 0.8603380065709937,
#   'मात्रै': 1.1613680022349748,
#   'उत्पादन': 0.6842467475153124,
#   'भनिए': 1.462397997898956,
#   'आफूले': 0.9852767431792936,
#   'सुरुमा': 1.462397997898956,
#   'चुनौति': 1.462397997898956,
#   'मोलेर': 1.462397997898956,
#   'खेती': 0.7634279935629373,
#   'सुरु': 0.6842467475153124,
#   'बताए': 0.6842467475153124},
#  ' बीस–पच्ची': {'बीस–पच्चीस': 1.462397997898956,
#   'वर्षअघि': 1.462397997898956,
#   'ककनीमा': 1.462397997898956,
#   'जाइटी': 1.462397997898956,
#   'संस्थाले': 1.462397997898956,
#   'स्ट्रबेरीको': 0.7634279935629373,
#   'खेती': 0.7634279935629373,
#   'सुरु': 0.6842467475153124,
#   'गरेपछि': 1.462397997898956,
#   'नुवाकोटमा': 0.8603380065709937,
#   'थालनी': 1.462397997898956,
#   'किसानहरुले': 1.462397997898956,
#   'प्रविधिको': 1.1613680022349748,
#   'प्रयोग': 0.8603380065709937,
#   'थिएनन्': 1.462397997898956},
#  ' ‘मैले नुव': {'‘मैले': 1.462397997898956,
#   'नुवाकोटमा': 0.8603380065709937,
#   'ग्रीन': 1.462397997898956,
#   'हाउस': 1.462397997898956,
#   'बनाउने': 1.462397997898956,
#   'थोपा': 0.9852767431792936,
#   'सिँचाइको': 1.462397997898956,
#   'काम': 0.7634279935629373,
#   'थिएँ’': 1.462397997898956,
#   'भने,': 1.1613680022349748,
#   '‘नुवाकोटमा': 1.462397997898956,
#   'आधारमा': 1.462397997898956,
#   'मैले': 1.462397997898956,
#   'काठमाडौंमा': 1.462397997898956,
#   'स्ट्रबेरी': 0.8603380065709937,
#   'लगाएको': 1.1613680022349748},
#  '’ अधिकारीक': {'’': 0.8603380065709937,
#   'अधिकारीको': 1.1613680022349748,
#   'फर्ममा': 1.462397997898956,
#   'अहिले': 1.462397997898956,
#   'स्ट्रबेरी': 0.8603380065709937,
#   'फल्न': 1.462397997898956,
#   'सुरु': 0.6842467475153124},
#  ' भदौमा लगा': {'भदौमा': 1.462397997898956,
#   'लगाएको': 1.1613680022349748,
#   'स्ट्रबेरीले': 1.462397997898956,
#   'कात्तिकको': 1.462397997898956,
#   'तेश्रो': 1.462397997898956,
#   'साता': 1.462397997898956,
#   'फलदिन': 1.462397997898956,
#   'सुरु': 0.6842467475153124},
#  ' मंसिरदेखि': {'मंसिरदेखि': 1.462397997898956,
#   'फागुनसम्म': 1.462397997898956,
#   'उत्पादन': 0.6842467475153124,
#   'राम्रोसँग': 1.462397997898956},
#  ' ५ देखि २५': {'५': 1.462397997898956,
#   '२५': 1.462397997898956,
#   'डिग्री': 1.462397997898956,
#   'तापक्रममा': 1.462397997898956,
#   'स्ट्रबेरी': 0.8603380065709937,
#   'लगाउन': 1.462397997898956,
#   'सकिन्छ': 0.9852767431792936},
#  ' विशेष गरी': {'विशेष': 1.462397997898956,
#   'जापान,': 1.462397997898956,
#   'कोरिया,': 1.462397997898956,
#   'थाइल्याण्ड,': 1.462397997898956,
#   'इजरायल': 1.462397997898956,
#   'लगायतका': 1.462397997898956,
#   'देशमा': 1.462397997898956,
#   'उत्पादन': 0.6842467475153124},
#  ' यी देशहरु': {'देशहरुले': 1.462397997898956,
#   'स्ट्रबेरीको': 0.7634279935629373,
#   'निर्यात': 1.1613680022349748,
#   'समेत': 0.7634279935629373},
#  ' बालक देखि': {'बालक': 1.462397997898956,
#   'बृद्धसम्म': 1.462397997898956,
#   'प्रयोग': 0.8603380065709937,
#   'उपयोगी': 1.462397997898956,
#   'मानिएको': 1.462397997898956},
#  ' विभिन्न श': {'विभिन्न': 0.9852767431792936,
#   'शुभ': 1.462397997898956,
#   'कार्यहरुमा': 1.462397997898956,
#   'समेत': 0.7634279935629373,
#   'स्ट्रबेरीलाई': 1.462397997898956,
#   'प्याक': 1.462397997898956,
#   'उपहारको': 1.462397997898956,
#   'रुपमा': 1.1613680022349748,
#   'दिइन्छ': 1.462397997898956},
#  ' जुनसुकै उ': {'जुनसुकै': 1.462397997898956,
#   'उमेर': 1.462397997898956,
#   'समुहका': 1.462397997898956,
#   'व्यक्तिका': 1.462397997898956,
#   'फाइदाजनक': 1.462397997898956,
#   'भएकोले': 1.462397997898956,
#   'ति': 1.462397997898956,
#   'देशहरुमा': 1.462397997898956,
#   'उत्पादन': 0.6842467475153124,
#   'बढ्दै': 1.462397997898956,
#   'गएको': 1.462397997898956,
#   'अधिकारीले': 0.7634279935629373,
#   'बताए': 0.6842467475153124},
#  ' ‘नेपालमा ': {'‘नेपालमा': 1.462397997898956,
#   'स्ट्रबेरीको': 0.7634279935629373,
#   'उत्पादन': 0.6842467475153124,
#   'सके': 1.1613680022349748,
#   'बजार': 1.462397997898956,
#   'छ,': 1.462397997898956,
#   'अर्कोतिर': 1.462397997898956,
#   'निर्यात': 1.1613680022349748,
#   'समेत': 0.7634279935629373,
#   'सकिन्छ': 0.9852767431792936},
#  '’ उनले भने': {'’': 0.8603380065709937,
#   'भने,': 1.1613680022349748,
#   '‘यसले': 1.462397997898956,
#   'किसानको': 1.462397997898956,
#   'जीवनस्तरलाई': 1.462397997898956,
#   'उकास्छ': 1.462397997898956,
#   'नेपालीहरु': 1.462397997898956,
#   'विदेसिनु': 1.462397997898956,
#   'समेत': 0.7634279935629373,
#   'पर्दैन': 1.462397997898956},
#  '’ स्ट्रबेर': {'’': 0.8603380065709937,
#   'स्ट्रबेरीको': 0.7634279935629373,
#   'जाम': 1.462397997898956,
#   'विश्वमै': 1.462397997898956,
#   'चर्चित': 1.462397997898956,
#   'बताए': 0.6842467475153124},
#  ' स्ट्रबेरी': {'स्ट्रबेरीबाट': 1.462397997898956,
#   'रक्सी': 1.462397997898956,
#   'जुस': 1.462397997898956,
#   'बनाउन': 1.462397997898956,
#   'सकिन्छ': 0.9852767431792936},
#  '‘आफ्नो जति': {'‘आफ्नो': 1.462397997898956,
#   'जति': 1.462397997898956,
#   'जग्गा': 1.462397997898956,
#   'त्यतिमा': 1.462397997898956,
#   'मात्रै': 1.1613680022349748,
#   'खेती': 0.7634279935629373,
#   'सके': 1.1613680022349748,
#   'यसले': 1.462397997898956,
#   'किसानलाई': 1.462397997898956,
#   'फाइदा': 1.462397997898956,
#   'पुग्छ': 1.462397997898956},
#  '’ विदेशमा ': {'’': 0.8603380065709937,
#   'विदेशमा': 1.1613680022349748,
#   'लामो': 1.462397997898956,
#   'समयसम्म': 1.462397997898956,
#   'काम': 0.7634279935629373,
#   'गरेकोले': 1.462397997898956,
#   'आफूले': 0.9852767431792936,
#   'स्वदेशमा': 1.462397997898956,
#   'बसेर': 0.9852767431792936,
#   'खोजेको': 1.462397997898956,
#   'बताए': 0.6842467475153124},
#  ' विदेशमा ब': {'विदेशमा': 1.1613680022349748,
#   'बसेर': 0.9852767431792936,
#   'काम': 0.7634279935629373,
#   'फर्किएकाहरुको': 1.462397997898956,
#   'संस्था': 1.462397997898956,
#   'एसियन': 1.462397997898956,
#   'फोरमका': 1.462397997898956,
#   'सचिव': 1.462397997898956,
#   'समेत': 0.7634279935629373,
#   'अधिकारीले': 0.7634279935629373,
#   'समयमा': 1.462397997898956,
#   'नेपालीहरुले': 1.462397997898956,
#   'आधुनिक': 1.462397997898956,
#   'प्रविधिको': 1.1613680022349748,
#   'प्रयोग': 0.8603380065709937,
#   'कृषि': 1.1613680022349748,
#   'पेशा': 1.462397997898956,
#   'अंगालेको': 1.462397997898956,
#   'बताए': 0.6842467475153124},
#  ' ग्रीनहाउस': {'ग्रीनहाउस': 1.462397997898956,
#   'बनाएर': 1.462397997898956,
#   'थोपा': 0.9852767431792936,
#   'सिँचाई': 1.462397997898956,
#   'मार्फत': 1.462397997898956,
#   'आफूले': 0.9852767431792936,
#   'देशका': 1.462397997898956,
#   'विभिन्न': 0.9852767431792936,
#   'ठाउँहरुमा': 1.462397997898956,
#   'तरकारी': 1.462397997898956,
#   'खेती': 0.7634279935629373,
#   'सेवा': 1.1613680022349748,
#   'उपलब्ध': 1.1613680022349748,
#   'गराएको': 1.462397997898956,
#   'अधिकारीको': 1.1613680022349748,
#   'भनाइ': 1.462397997898956},
#  ' नेपालमा प': {'नेपालमा': 1.462397997898956,
#   'पहिलोपटक': 1.462397997898956,
#   'थोपा': 0.9852767431792936,
#   'सिंचाइलाई': 1.462397997898956,
#   'व्यवसायिक': 1.1613680022349748,
#   'रुपमा': 1.1613680022349748,
#   'आफैले': 1.462397997898956,
#   'प्रयोग': 0.8603380065709937,
#   'दावी': 1.462397997898956,
#   'गरे': 1.462397997898956},
#  '': {}}

# %% [markdown]
# ## term frequency and inverse document frequency matrix

# %%
def create_tf_idf_matrix(tf_matrix, idf_matrix):
    tf_idf_matrix = {}

    for (sent1, f_table1), (sent2, f_table2) in zip(tf_matrix.items(), idf_matrix.items()):

        tf_idf_table = {}

        for (word1, value1), (word2, value2) in zip(f_table1.items(),
                                                    f_table2.items()):  
            tf_idf_table[word1] = float(value1 * value2)

        tf_idf_matrix[sent1] = tf_idf_table

    return tf_idf_matrix

# %%
tf_idf_matrix = create_tf_idf_matrix(tf_matrix, idf_matrix)

# %%
tf_idf_matrix
# Out:
# {'\ufeffकाठमाडौंम': {'\ufeffकाठमाडौंमा': 0.29247959957979125,
#   'स्ट्रबेरीको': 0.15268559871258747,
#   'व्यवसायिक': 0.23227360044699497,
#   'खेती': 0.15268559871258747,
#   'सुरु': 0.1368493495030625},
#  ' एक दशकसम्': {'दशकसम्म': 0.10445699984992543,
#   'इजरायली': 0.10445699984992543,
#   'कृषि': 0.0829548573024982,
#   'फार्ममा': 0.10445699984992543,
#   'बसेर': 0.0703769102270924,
#   'काम': 0.054530570968781236,
#   'श्रीकृष्ण': 0.10445699984992543,
#   'अधिकारीले': 0.054530570968781236,
#   'तारकेश्वर': 0.10445699984992543,
#   'नगरपालिका': 0.10445699984992543,
#   '४': 0.10445699984992543,
#   'गोलढुंगामा': 0.10445699984992543,
#   'उत्पादन': 0.04887476767966517,
#   'सुरु': 0.04887476767966517},
#  ' यसअघि स्ट': {'यसअघि': 0.29247959957979125,
#   'स्ट्रबेरी': 0.17206760131419874,
#   'नुवाकोटमा': 0.17206760131419874,
#   'गरिँदै': 0.29247959957979125,
#   'आएको': 0.23227360044699497},
#  ' अधिकारीले': {'अधिकारीले': 0.054530570968781236,
#   'स्थापना': 0.10445699984992543,
#   'सलोम': 0.10445699984992543,
#   'एग्रीकल्चर': 0.10445699984992543,
#   'नामक': 0.10445699984992543,
#   'कम्पनीले': 0.10445699984992543,
#   'कृषिमा': 0.10445699984992543,
#   'आधुनिकीकरणका': 0.10445699984992543,
#   'विभिन्न': 0.0703769102270924,
#   'खालका': 0.10445699984992543,
#   'सेवा': 0.0829548573024982,
#   'उपलब्ध': 0.0829548573024982,
#   'गराउँदै': 0.10445699984992543,
#   'आएको': 0.0829548573024982},
#  ' १० हजार म': {'१०': 0.14623979978989562,
#   'हजार': 0.14623979978989562,
#   'मध्ये': 0.14623979978989562,
#   '१': 0.14623979978989562,
#   'प्रतिशत': 0.14623979978989562,
#   'बिरुवा': 0.14623979978989562,
#   'काम': 0.07634279935629373,
#   'नलागेको': 0.14623979978989562,
#   'अधिकारीले': 0.07634279935629373,
#   'बताए': 0.06842467475153124},
#  ' अहिलेसम्म': {'अहिलेसम्म': 0.121866499824913,
#   'नुवाकोटमा': 0.07169483388091613,
#   'मात्रै': 0.09678066685291456,
#   'उत्पादन': 0.0570205622929427,
#   'भनिए': 0.121866499824913,
#   'आफूले': 0.08210639526494112,
#   'सुरुमा': 0.121866499824913,
#   'चुनौति': 0.121866499824913,
#   'मोलेर': 0.121866499824913,
#   'खेती': 0.0636189994635781,
#   'सुरु': 0.0570205622929427,
#   'बताए': 0.0570205622929427},
#  ' बीस–पच्ची': {'बीस–पच्चीस': 0.09749319985993041,
#   'वर्षअघि': 0.09749319985993041,
#   'ककनीमा': 0.09749319985993041,
#   'जाइटी': 0.09749319985993041,
#   'संस्थाले': 0.09749319985993041,
#   'स्ट्रबेरीको': 0.05089519957086249,
#   'खेती': 0.10179039914172498,
#   'सुरु': 0.09123289966870833,
#   'गरेपछि': 0.09749319985993041,
#   'नुवाकोटमा': 0.057355867104732915,
#   'थालनी': 0.09749319985993041,
#   'किसानहरुले': 0.09749319985993041,
#   'प्रविधिको': 0.07742453348233165,
#   'प्रयोग': 0.057355867104732915,
#   'थिएनन्': 0.09749319985993041},
#  ' ‘मैले नुव': {'‘मैले': 0.09139987486868476,
#   'नुवाकोटमा': 0.053771125410687105,
#   'ग्रीन': 0.09139987486868476,
#   'हाउस': 0.09139987486868476,
#   'बनाउने': 0.09139987486868476,
#   'थोपा': 0.06157979644870585,
#   'सिँचाइको': 0.09139987486868476,
#   'काम': 0.04771424959768358,
#   'थिएँ’': 0.09139987486868476,
#   'भने,': 0.07258550013968593,
#   '‘नुवाकोटमा': 0.09139987486868476,
#   'आधारमा': 0.09139987486868476,
#   'मैले': 0.09139987486868476,
#   'काठमाडौंमा': 0.09139987486868476,
#   'स्ट्रबेरी': 0.053771125410687105,
#   'लगाएको': 0.07258550013968593},
#  '’ अधिकारीक': {'’': 0.12290542951014195,
#   'अधिकारीको': 0.1659097146049964,
#   'फर्ममा': 0.20891399969985086,
#   'अहिले': 0.20891399969985086,
#   'स्ट्रबेरी': 0.12290542951014195,
#   'फल्न': 0.20891399969985086,
#   'सुरु': 0.09774953535933034},
#  ' भदौमा लगा': {'भदौमा': 0.1827997497373695,
#   'लगाएको': 0.14517100027937185,
#   'स्ट्रबेरीले': 0.1827997497373695,
#   'कात्तिकको': 0.1827997497373695,
#   'तेश्रो': 0.1827997497373695,
#   'साता': 0.1827997497373695,
#   'फलदिन': 0.1827997497373695,
#   'सुरु': 0.08553084343941406},
#  ' मंसिरदेखि': {'मंसिरदेखि': 0.365599499474739,
#   'फागुनसम्म': 0.365599499474739,
#   'उत्पादन': 0.1710616868788281,
#   'राम्रोसँग': 0.365599499474739},
#  ' ५ देखि २५': {'५': 0.20891399969985086,
#   '२५': 0.20891399969985086,
#   'डिग्री': 0.20891399969985086,
#   'तापक्रममा': 0.20891399969985086,
#   'स्ट्रबेरी': 0.12290542951014195,
#   'लगाउन': 0.20891399969985086,
#   'सकिन्छ': 0.1407538204541848},
#  ' विशेष गरी': {'विशेष': 0.1827997497373695,
#   'जापान,': 0.1827997497373695,
#   'कोरिया,': 0.1827997497373695,
#   'थाइल्याण्ड,': 0.1827997497373695,
#   'इजरायल': 0.1827997497373695,
#   'लगायतका': 0.1827997497373695,
#   'देशमा': 0.1827997497373695,
#   'उत्पादन': 0.08553084343941406},
#  ' यी देशहरु': {'देशहरुले': 0.365599499474739,
#   'स्ट्रबेरीको': 0.19085699839073433,
#   'निर्यात': 0.2903420005587437,
#   'समेत': 0.19085699839073433},
#  ' बालक देखि': {'बालक': 0.29247959957979125,
#   'बृद्धसम्म': 0.29247959957979125,
#   'प्रयोग': 0.17206760131419874,
#   'उपयोगी': 0.29247959957979125,
#   'मानिएको': 0.29247959957979125},
#  ' विभिन्न श': {'विभिन्न': 0.10947519368658817,
#   'शुभ': 0.16248866643321733,
#   'कार्यहरुमा': 0.16248866643321733,
#   'समेत': 0.08482533261810414,
#   'स्ट्रबेरीलाई': 0.16248866643321733,
#   'प्याक': 0.16248866643321733,
#   'उपहारको': 0.16248866643321733,
#   'रुपमा': 0.12904088913721942,
#   'दिइन्छ': 0.16248866643321733},
#  ' जुनसुकै उ': {'जुनसुकै': 0.11249215368453509,
#   'उमेर': 0.11249215368453509,
#   'समुहका': 0.11249215368453509,
#   'व्यक्तिका': 0.11249215368453509,
#   'फाइदाजनक': 0.11249215368453509,
#   'भएकोले': 0.11249215368453509,
#   'ति': 0.11249215368453509,
#   'देशहरुमा': 0.11249215368453509,
#   'उत्पादन': 0.05263436519348558,
#   'बढ्दै': 0.11249215368453509,
#   'गएको': 0.11249215368453509,
#   'अधिकारीले': 0.05872523027407211,
#   'बताए': 0.05263436519348558},
#  ' ‘नेपालमा ': {'‘नेपालमा': 0.14623979978989562,
#   'स्ट्रबेरीको': 0.07634279935629373,
#   'उत्पादन': 0.06842467475153124,
#   'सके': 0.11613680022349748,
#   'बजार': 0.14623979978989562,
#   'छ,': 0.14623979978989562,
#   'अर्कोतिर': 0.14623979978989562,
#   'निर्यात': 0.11613680022349748,
#   'समेत': 0.07634279935629373,
#   'सकिन्छ': 0.09852767431792936},
#  '’ उनले भने': {'’': 0.08603380065709937,
#   'भने,': 0.11613680022349748,
#   '‘यसले': 0.14623979978989562,
#   'किसानको': 0.14623979978989562,
#   'जीवनस्तरलाई': 0.14623979978989562,
#   'उकास्छ': 0.14623979978989562,
#   'नेपालीहरु': 0.14623979978989562,
#   'विदेसिनु': 0.14623979978989562,
#   'समेत': 0.07634279935629373,
#   'पर्दैन': 0.14623979978989562},
#  '’ स्ट्रबेर': {'’': 0.14338966776183226,
#   'स्ट्रबेरीको': 0.1272379989271562,
#   'जाम': 0.243732999649826,
#   'विश्वमै': 0.243732999649826,
#   'चर्चित': 0.243732999649826,
#   'बताए': 0.1140411245858854},
#  ' स्ट्रबेरी': {'स्ट्रबेरीबाट': 0.29247959957979125,
#   'रक्सी': 0.29247959957979125,
#   'जुस': 0.29247959957979125,
#   'बनाउन': 0.29247959957979125,
#   'सकिन्छ': 0.19705534863585872},
#  '‘आफ्नो जति': {'‘आफ्नो': 0.13294527253626873,
#   'जति': 0.13294527253626873,
#   'जग्गा': 0.13294527253626873,
#   'त्यतिमा': 0.13294527253626873,
#   'मात्रै': 0.10557890929408863,
#   'खेती': 0.06940254486935794,
#   'सके': 0.10557890929408863,
#   'यसले': 0.13294527253626873,
#   'किसानलाई': 0.13294527253626873,
#   'फाइदा': 0.13294527253626873,
#   'पुग्छ': 0.13294527253626873},
#  '’ विदेशमा ': {'’': 0.07821254605190851,
#   'विदेशमा': 0.10557890929408863,
#   'लामो': 0.13294527253626873,
#   'समयसम्म': 0.13294527253626873,
#   'काम': 0.06940254486935794,
#   'गरेकोले': 0.13294527253626873,
#   'आफूले': 0.08957061301629941,
#   'स्वदेशमा': 0.13294527253626873,
#   'बसेर': 0.08957061301629941,
#   'खोजेको': 0.13294527253626873,
#   'बताए': 0.06220424977411931},
#  ' विदेशमा ब': {'विदेशमा': 0.06112463169657762,
#   'बसेर': 0.05185667069364703,
#   'काम': 0.0401804207138388,
#   'फर्किएकाहरुको': 0.07696831567889242,
#   'संस्था': 0.07696831567889242,
#   'एसियन': 0.07696831567889242,
#   'फोरमका': 0.07696831567889242,
#   'सचिव': 0.07696831567889242,
#   'समेत': 0.0401804207138388,
#   'अधिकारीले': 0.0401804207138388,
#   'समयमा': 0.07696831567889242,
#   'नेपालीहरुले': 0.07696831567889242,
#   'आधुनिक': 0.07696831567889242,
#   'प्रविधिको': 0.06112463169657762,
#   'प्रयोग': 0.045280947714262824,
#   'कृषि': 0.06112463169657762,
#   'पेशा': 0.07696831567889242,
#   'अंगालेको': 0.07696831567889242,
#   'बताए': 0.03601298671133223},
#  ' ग्रीनहाउस': {'ग्रीनहाउस': 0.09139987486868476,
#   'बनाएर': 0.09139987486868476,
#   'थोपा': 0.06157979644870585,
#   'सिँचाई': 0.09139987486868476,
#   'मार्फत': 0.09139987486868476,
#   'आफूले': 0.06157979644870585,
#   'देशका': 0.09139987486868476,
#   'विभिन्न': 0.06157979644870585,
#   'ठाउँहरुमा': 0.09139987486868476,
#   'तरकारी': 0.09139987486868476,
#   'खेती': 0.04771424959768358,
#   'सेवा': 0.07258550013968593,
#   'उपलब्ध': 0.07258550013968593,
#   'गराएको': 0.09139987486868476,
#   'अधिकारीको': 0.07258550013968593,
#   'भनाइ': 0.09139987486868476},
#  ' नेपालमा प': {'नेपालमा': 0.14623979978989562,
#   'पहिलोपटक': 0.14623979978989562,
#   'थोपा': 0.09852767431792936,
#   'सिंचाइलाई': 0.14623979978989562,
#   'व्यवसायिक': 0.11613680022349748,
#   'रुपमा': 0.11613680022349748,
#   'आफैले': 0.14623979978989562,
#   'प्रयोग': 0.08603380065709937,
#   'दावी': 0.14623979978989562,
#   'गरे': 0.14623979978989562},
#  '': {}}

# %% [markdown]
# ## calculate sentence scores

# %%
def sentence_scores(tf_idf_matrix) -> dict:
    

    sentenceValue = {}

    for sent, f_table in tf_idf_matrix.items():
        total_score_per_sentence = 0

        count_words_in_sentence = len(f_table)
        for word, score in f_table.items():
            total_score_per_sentence += score
        if count_words_in_sentence !=0:
            sentenceValue[sent] = total_score_per_sentence / count_words_in_sentence
        else:
            sentenceValue[sent]=0
    return sentenceValue

# %%
sentence_scores = sentence_scores(tf_idf_matrix)

# %%
print(sentence_scores)
# Out:
# {'\ufeffकाठमाडौंम': 0.19339474939100473, ' एक दशकसम्': 0.08541417454470622, ' यसअघि स्ट': 0.23227360044699502, ' अधिकारीले': 0.0938489322680498, ' १० हजार म': 0.12447888719933879, ' अहिलेसम्म': 0.09121625678881194, ' बीस–पच्ची': 0.08756623765416446, ' ‘मैले नुव': 0.07975037786462395, '’ अधिकारीक': 0.16231601544059474, ' भदौमा लगा': 0.16593754276787534, ' मंसिरदेखि': 0.3169650463257613, ' ५ देखि २५': 0.1868898926376544, ' विशेष गरी': 0.17064113645012505, ' यी देशहरु': 0.25941387420373785, ' बालक देखि': 0.26839719992667277, ' विभिन्न श': 0.14425260156013506, ' जुनसुकै उ': 0.09914734596203033, ' ‘नेपालमा ': 0.11368707473886257, '’ उनले भने': 0.130219199876616, '’ स्ट्रबेर': 0.18597796503739197, ' स्ट्रबेरी': 0.2733947493910048, '‘आफ्नो जति': 0.12219295852251683, '’ विदेशमा ': 0.10538780351849245, ' विदेशमा ब': 0.06351310100733765, ' ग्रीनहाउस': 0.07955056332381387, ' नेपालमा प': 0.12942738741613974, '': 0}

# %% [markdown]
# ## finding average to set threshold

# %%
def find_average_score(sentenceValue) -> int:
    sumValues = 0
    for entry in sentenceValue:
        sumValues += sentenceValue[entry]

    # Average value of a sentence from original summary_text
    average = (sumValues / len(sentenceValue))

    return average

# %%
#average sentence score is set as threshold, ..can try other
threshold = find_average_score(sentence_scores)

# %%
threshold
# Out:
# 0.14686128423201697

# %% [markdown]
# ## Finally Generate Summary

# %%
def generate_summary(sentences, sentenceValue, threshold):
    sentence_count = 0
    summary = []

    for sentence in sentences:
        if sentence[:10] in sentenceValue and sentenceValue[sentence[:10]] >= (threshold):
            summary.append(sentence)
            sentence_count += 1

    return summary

# %%
summary = '।'.join(generate_summary(sents, sentence_scores,0.8*threshold ))

# %%
print(summary)
# Out:
# ﻿काठमाडौंमा पहिलो पटक स्ट्रबेरीको व्यवसायिक खेती सुरु भएको छ । यसअघि स्ट्रबेरी नुवाकोटमा गरिँदै आएको थियो। १० हजार मध्ये १ प्रतिशत बिरुवा भने काम नलागेको अधिकारीले बताए।’ अधिकारीको फर्ममा अहिले स्ट्रबेरी फल्न सुरु गरेको छ। भदौमा लगाएको स्ट्रबेरीले कात्तिकको तेश्रो साता देखि फलदिन सुरु गर्छ। मंसिरदेखि फागुनसम्म भने यसको उत्पादन राम्रोसँग हुन्छ। ५ देखि २५ डिग्री तापक्रममा स्ट्रबेरी लगाउन सकिन्छ। विशेष गरी जापान, कोरिया, थाइल्याण्ड, इजरायल लगायतका देशमा यसको उत्पादन हुन्छ। यी देशहरुले स्ट्रबेरीको निर्यात समेत गर्ने गरेका छन्। बालक देखि बृद्धसम्म यसको प्रयोग उपयोगी मानिएको छ। विभिन्न शुभ कार्यहरुमा समेत स्ट्रबेरीलाई प्याक गरेर उपहारको रुपमा दिइन्छ।’ उनले भने, ‘विदेशबाट आयात गर्ने फलफूलको विकल्पमा स्ट्रबेरीलाई लिन सकिन्छ।’ स्ट्रबेरीको जाम विश्वमै चर्चित रहेको उनले बताए। स्ट्रबेरीबाट रक्सी तथा जुस पनि बनाउन सकिन्छ।‘आफ्नो जति जग्गा छ त्यतिमा मात्रै खेती गर्न सके पनि यसले किसानलाई फाइदा पुग्छ।’ उनले भने, ‘यसले किसानको जीवनस्तरलाई त उकास्छ नै नेपालीहरु विदेसिनु समेत पर्दैन। नेपालमा पहिलोपटक थोपा सिंचाइलाई व्यवसायिक रुपमा आफैले प्रयोग गरेको उनले दावी गरे

# %%
len(summary)
# Out:
# 1060
